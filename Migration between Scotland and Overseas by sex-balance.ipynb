# %% [markdown]
# tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx'
inputFile = sourceFolder / 'tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Net-Council Area-Sex')[0]
# Out:
# Loading in\tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx which has size 102586 bytes
# Table names: ['Net-Council Area-Sex']

# %%
observations = tab.excel_ref("B6").expand(RIGHT).expand(DOWN).is_not_blank().is_not_whitespace()
observations
# Out:
# {<O94 3371.0>, <J50 681.0>, <P100 -16.0>, <O46 -39.0>, <M19 -54.0>, <P88 3.0>, <I55 52.0>, <I104 73.0>, <H88 -31.0>, <Q102 2.0>, <G81 448.0>, <F36 -109.0>, <Q99 3.0>, <M35 -53.0>, <L13 565.0>, <B84 948.0>, <L53 -12.0>, <B96 24.0>, <J96 5.0>, <I37 428.0>, <J81 417.0>, <C97 -36.0>, <I15 -29.0>, <H12 -175.0>, <O26 -42.0>, <P79 '2015-16'>, <E54 -64.0>, <J99 -2.0>, <B46 -158.0>, <F110 -18.0>, <G60 55.0>, <N64 -93.0>, <I107 -27.0>, <L19 359.0>, <B90 18.0>, <K94 3307.0>, <G7 836.0>, <B42 '2001-02'>, <F32 -42.0>, <I100 -40.0>, <K8 235.0>, <B77 'Net-migration - Females'>, <D48 -19.0>, <H67 70.0>, <P86 18.0>, <J26 -91.0>, <O49 -48.0>, <K61 -26.0>, <N34 -373.0>, <G96 30.0>, <M85 -25.0>, <D93 133.0>, <G69 10.0>, <D111 -24.0>, <C44 -243.0>, <F61 24.0>, <I94 2433.0>, <P98 27.0>, <L104 -18.0>, <M31 -173.0>, <M56 -87.0>, <G106 4.0>, <J93 714.0>, <D96 -65.0>, <K23 73.0>, <N96 -17.0>, <N111 36.0>, <O83 -46.0>, <J12 -162.0>, <J74 219.0>, <B17 -35.0>, <G79 '2006-07'>, <N30 -8.0>, <D79 '2003-04'>, <E62 1.0>, <K93 756.0>, <Q106 -10.0>, <H95 81.0>, <P91 39.0>, <M20 2065.0>, <B58 -83.0>, <K30 456.0>, <H19 384.0>, <J44 302.0>, <K111 243.0>, <E58 287.0>, <E88 -41.0>, <L49 -154.0>, <G14 -67.0>, <J61 43.0>, <L27 -204.0>, <B28 -28.0>, <Q68 14.0>, <O34 -161.0>, <F43 1097.0>, <P101 131.0>, <K20 7060.0>, <M33 -193.0>, <G104 242.0>, <K98 -69.0>, <H102 -12.0>, <D91 -72.0>, <F90 15.0>, <D87 54.0>, <F69 -26.0>, <D71 -207.0>, <K55 142.0>, <L12 -280.0>, <Q105 3.0>, <B29 79.0>, <C53 -18.0>, <H82 28.0>, <O98 -98.0>, <K71 8.0>, <C15 -133.0>, <F29 970.0>, <M14 -161.0>, <M106 -19.0>, <M101 -143.0>, <L73 -24.0>, <G20 4740.0>, <I111 172.0>, <B13 50.0>, <L7 209.0>, <G10 6121.0>, <E63 -112.0>, <G101 273.0>, <I102 -4.0>, <E71 -177.0>, <O19 828.0>, <P66 209.0>, <F97 1.0>, <I10 6271.0>, <H15 -121.0>, <B64 -210.0>, <C47 660.0>, <B41 'Year'>, <B7 -138.0>, <F68 10.0>, <K89 -29.0>, <O73 -23.0>, <I44 254.0>, <F88 -102.0>, <N18 15.0>, <L42 '2011-12'>, <K16 166.0>, <N59 -46.0>, <J91 10.0>, <H36 -74.0>, <J105 -54.0>, <J82 130.0>, <O56 341.0>, <O18 127.0>, <P80 1404.0>, <E52 -41.0>, <N27 -165.0>, <C90 -20.0>, <B9 -277.0>, <J54 28.0>, <E68 41.0>, <B19 98.0>, <H8 107.0>, <H93 225.0>, <L15 -91.0>, <D54 -71.0>, <F70 -80.0>, <I27 19.0>, <D19 87.0>, <E18 246.0>, <M21 -243.0>, <N51 -87.0>, <P69 18.0>, <D28 -18.0>, <N14 -174.0>, <K70 45.0>, <D31 -61.0>, <K33 80.0>, <D42 '2003-04'>, <O105 -9.0>, <N82 22.0>, <O17 -83.0>, <H97 22.0>, <O85 4.0>, <H22 -52.0>, <C55 -7.0>, <L6 2102.0>, <P53 106.0>, <G54 -6.0>, <B102 -14.0>, <F16 37.0>, <E14 -87.0>, <B15 -55.0>, <O43 1488.0>, <P45 33.0>, <N97 -17.0>, <I16 216.0>, <M96 -24.0>, <Q108 -24.0>, <M62 -32.0>, <N98 -37.0>, <M23 -45.0>, <O89 -51.0>, <M94 1138.0>, <E90 -2.0>, <L68 -47.0>, <I9 -51.0>, <M63 -133.0>, <C14 -220.0>, <G74 483.0>, <C83 -60.0>, <D20 1099.0>, <P20 7935.0>, <H11 -12.0>, <L98 -77.0>, <O53 36.0>, <I8 145.0>, <H35 259.0>, <I99 4.0>, <B111 -61.0>, <P22 39.0>, <G82 70.0>, <E79 '2004-05'>, <M26 -238.0>, <M99 -27.0>, <N86 -121.0>, <L55 -7.0>, <O23 -20.0>, <D81 76.0>, <E85 18.0>, <L62 -23.0>, <M47 630.0>, <H51 -62.0>, <K102 -5.0>, <M109 31.0>, <P82 40.0>, <F55 21.0>, <K27 116.0>, <F81 384.0>, <C65 -19.0>, <G62 6.0>, <F26 -278.0>, <E50 364.0>, <L65 -20.0>, <N11 -26.0>, <M16 -52.0>, <O36 -33.0>, <B27 -376.0>, <D108 -161.0>, <E69 -17.0>, <I48 25.0>, <L18 -29.0>, <F111 268.0>, <K52 -44.0>, <K22 -25.0>, <D51 -79.0>, <L69 -5.0>, <Q48 10.0>, <O107 12.0>, <D82 -64.0>, <H73 -34.0>, <C17 -66.0>, <D73 -57.0>, <G11 158.0>, <N67 -12.0>, <D101 -120.0>, <B67 -83.0>, <H89 -67.0>, <F105 1.0>, <K50 807.0>, <H44 203.0>, <C31 -262.0>, <F20 1065.0>, <K88 -28.0>, <K11 6.0>, <D57 523.0>, <J94 2531.0>, <B99 -11.0>, <K17 -27.0>, <C74 -114.0>, <H94 1983.0>, <O108 -53.0>, <H6 3030.0>, <F49 -72.0>, <C111 -79.0>, <L93 280.0>, <D95 120.0>, <I33 -106.0>, <D45 -42.0>, <N63 -111.0>, <K90 119.0>, <H71 -102.0>, <N109 33.0>, <M84 1323.0>, <J31 -103.0>, <C87 98.0>, <L16 116.0>, <Q17 -8.0>, <N8 27.0>, <J69 16.0>, <J34 -56.0>, <Q46 -11.0>, <Q111 79.0>, <P10 6791.0>, <G26 -47.0>, <M9 ...

# %%
observations = observations - tab.excel_ref('B').expand(DOWN).by_index([40,41,42,77,78,79])

# %%
area = tab.excel_ref('A6').expand(DOWN).is_not_blank() - tab.excel_ref('A').expand(DOWN).by_index([40,41,42,77,78,79])
area
# Out:
# {<A52 'East Dunbartonshire'>, <A84 'City of Edinburgh'>, <A47 'City of Edinburgh'>, <A91 'East Renfrewshire'>, <A113 'Footnote'>, <A46 'Argyll & Bute'>, <A109 'Stirling'>, <A67 'Renfrewshire'>, <A70 'South Ayrshire'>, <A10 'City of Edinburgh'>, <A44 'Aberdeenshire'>, <A54 'East Renfrewshire'>, <A95 'Highland'>, <A102 'Orkney Islands'>, <A13 'Dundee City'>, <A50 'Dundee City'>, <A61 'Moray'>, <A111 'West Lothian'>, <A53 'East Lothian'>, <A23 'Midlothian'>, <A65 'Orkney Islands'>, <A85 'Clackmannanshire'>, <A59 'Inverclyde'>, <A96 'Inverclyde'>, <A87 'Dundee City'>, <A18 'Falkirk'>, <A108 'South Lanarkshire'>, <A86 'Dumfries and Galloway'>, <A14 'East Ayrshire'>, <A105 'Scottish Borders'>, <A63 'North Ayrshire'>, <A34 'South Lanarkshire'>, <A80 'Aberdeen City'>, <A15 'East Dunbartonshire'>, <A103 'Perth and Kinross'>, <A30 'Renfrewshire'>, <A82 'Angus'>, <A9 'Argyll & Bute'>, <A35 'Stirling'>, <A56 'Fife'>, <A28 'Orkney Islands'>, <A106 'Shetland Islands'>, <A66 'Perth and Kinross'>, <A68 'Scottish Borders'>, <A71 'South Lanarkshire'>, <A8 'Angus'>, <A26 'North Ayrshire'>, <A81 'Aberdeenshire'>, <A27 'North Lanarkshire'>, <A114 '1) Please note that asylum seekers are included for estimates for all years, refugees are included in 2015-16 estimates and onwards.'>, <A99 'Na h-Eileanan Siar'>, <A7 'Aberdeenshire'>, <A73 'West Dunbartonshire'>, <A33 'South Ayrshire'>, <A24 'Moray'>, <A43 'Aberdeen City'>, <A57 'Glasgow City'>, <A19 'Fife'>, <A51 'East Ayrshire'>, <A69 'Shetland Islands'>, <A55 'Falkirk'>, <A94 'Glasgow City'>, <A100 'North Ayrshire'>, <A101 'North Lanarkshire'>, <A17 'East Renfrewshire'>, <A90 'East Lothian'>, <A6 'Aberdeen City'>, <A92 'Falkirk'>, <A16 'East Lothian'>, <A116 '© Crown Copyright 2018'>, <A25 'Na h-Eileanan Siar'>, <A21 'Highland'>, <A48 'Clackmannanshire'>, <A36 'West Dunbartonshire'>, <A62 'Na h-Eileanan Siar'>, <A97 'Midlothian'>, <A29 'Perth and Kinross'>, <A104 'Renfrewshire'>, <A45 'Angus'>, <A89 'East Dunbartonshire'>, <A22 'Inverclyde'>, <A49 'Dumfries and Galloway'>, <A58 'Highland'>, <A37 'West Lothian'>, <A88 'East Ayrshire'>, <A72 'Stirling'>, <A107 'South Ayrshire'>, <A64 'North Lanarkshire'>, <A110 'West Dunbartonshire'>, <A93 'Fife'>, <A98 'Moray'>, <A32 'Shetland Islands'>, <A11 'Clackmannanshire'>, <A31 'Scottish Borders'>, <A20 'Glasgow City'>, <A12 'Dumfries and Galloway'>, <A83 'Argyll & Bute'>, <A60 'Midlothian'>, <A74 'West Lothian'>}

# %%
flow = tab.excel_ref('B').expand(DOWN).by_index([3,40,77])
flow
# Out:
# {<B77 'Net-migration - Females'>, <B40 'Net-migration - Males'>, <B3 'Net-migration - Persons'>}

# %%
midyear = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
midyear
# Out:
# {<G5 '2006-07'>, <K5 '2010-11'>, <D5 '2003-04'>, <E5 '2004-05'>, <J5 '2009-10'>, <P5 '2015-16'>, <I5 '2008-09'>, <N5 '2013-14'>, <C5 '2002-03'>, <L5 '2011-12'>, <Q5 '2016-17'>, <F5 '2005-06'>, <H5 '2007-08'>, <B5 '2001-02'>, <M5 '2012-13'>, <O5 '2014-15'>}

# %%
Dimensions = [
            HDim(midyear,'Mid Year',DIRECTLY,ABOVE),
            HDim(area,'Area of Destination or Origin', DIRECTLY, LEFT),
            HDim(flow,'flow',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Flow','Balance'),
            HDimConst('Age', 'all')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#          OBS DATAMARKER Mid Year Area of Destination or Origin  \
# 0      833.0        NaN  2001-02                 Aberdeen City
# 1      385.0        NaN  2002-03                 Aberdeen City
# 2      874.0        NaN  2003-04                 Aberdeen City
# 3     2150.0        NaN  2004-05                 Aberdeen City
# 4     2138.0        NaN  2005-06                 Aberdeen City
# 5     3752.0        NaN  2006-07                 Aberdeen City
# 6     3030.0        NaN  2007-08                 Aberdeen City
# 7     3669.0        NaN  2008-09                 Aberdeen City
# 8     3742.0        NaN  2009-10                 Aberdeen City
# 9     4130.0        NaN  2010-11                 Aberdeen City
# 10    2102.0        NaN  2011-12                 Aberdeen City
# 11    1302.0        NaN  2012-13                 Aberdeen City
# 12    1965.0        NaN  2013-14                 Aberdeen City
# 13    3189.0        NaN  2014-15                 Aberdeen City
# 14    2474.0        NaN  2015-16                 Aberdeen City
# 15    1491.0        NaN  2016-17                 Aberdeen City
# 16    -138.0        NaN  2001-02                 Aberdeenshire
# 17    -334.0        NaN  2002-03                 Aberdeenshire
# 18     127.0        NaN  2003-04                 Aberdeenshire
# 19     623.0        NaN  2004-05                 Aberdeenshire
# 20     655.0        NaN  2005-06                 Aberdeenshire
# 21     836.0        NaN  2006-07                 Aberdeenshire
# 22     405.0        NaN  2007-08                 Aberdeenshire
# 23     605.0        NaN  2008-09                 Aberdeenshire
# 24     719.0        NaN  2009-10                 Aberdeenshire
# 25     723.0        NaN  2010-11                 Aberdeenshire
# 26     209.0        NaN  2011-12                 Aberdeenshire
# 27     116.0        NaN  2012-13                 Aberdeenshire
# 28     124.0        NaN  2013-14                 Aberdeenshire
# 29     256.0        NaN  2014-15                 Aberdeenshire
# ...      ...        ...      ...                           ...
# 1536   -41.0        NaN  2003-04           West Dunbartonshire
# 1537   -31.0        NaN  2004-05           West Dunbartonshire
# 1538   -18.0        NaN  2005-06           West Dunbartonshire
# 1539    21.0        NaN  2006-07           West Dunbartonshire
# 1540   -40.0        NaN  2007-08           West Dunbartonshire
# 1541   -32.0        NaN  2008-09           West Dunbartonshire
# 1542    26.0        NaN  2009-10           West Dunbartonshire
# 1543    25.0        NaN  2010-11           West Dunbartonshire
# 1544   -34.0        NaN  2011-12           West Dunbartonshire
# 1545   -21.0        NaN  2012-13           West Dunbartonshire
# 1546   -12.0        NaN  2013-14           West Dunbartonshire
# 1547   -10.0        NaN  2014-15           West Dunbartonshire
# 1548    49.0        NaN  2015-16           West Dunbartonshire
# 1549     2.0        NaN  2016-17           West Dunbartonshire
# 1550   -61.0        NaN  2001-02                  West Lothian
# 1551   -79.0        NaN  2002-03                  West Lothian
# 1552   -24.0        NaN  2003-04                  West Lothian
# 1553    91.0        NaN  2004-05                  West Lothian
# 1554   268.0        NaN  2005-06                  West Lothian
# 1555   410.0        NaN  2006-07                  West Lothian
# 1556   266.0        NaN  2007-08                  West Lothian
# 1557   172.0        NaN  2008-09                  West Lothian
# 1558   191.0        NaN  2009-10                  West Lothian
# 1559   243.0        NaN  2010-11                  West Lothian
# 1560   129.0        NaN  2011-12                  West Lothian
# 1561    14.0        NaN  2012-13                  West Lothian
# 1562    36.0        NaN  2013-14                  West Lothian
# 1563   103.0        NaN  2014-15                  West Lothian
# 1564   183.0        NaN  2015-16                  West Lothian
# 1565    79.0        NaN  2016-17                  West Lothian
#
#                          flow Measure Type    Unit     Flow  Age
# 0     Net-migration - Persons        Count  People  Balance  all
# 1     Net-migration - Persons        Count  People  Balance  all
# 2     Net-migration - Persons        Count  People  Balance  all
# 3     Net-migration - Persons        Count  People  Balance  all
# 4     Net-migration - Persons        Count  People  Balance  all
# 5     Net-migration - Persons        Count  People  Balance  all
# 6     Net-migration - Persons        Count  People  Balance  all
# 7     Net-migration - Persons        Count  People  Balance  all
# 8     Net-migration - Persons        Count  People  Balance  all
# 9     Net-migration - Persons        Count  People  Balance  all
# 10    Net-migration - Persons        Count  People  Balance  all
# 11    Net-migration - Persons        Count  People  Balance  all
# 12    Net-migration - Persons        Count  People  Balance  all
# 13    Net-migration - Persons        Count  People  Balance  all
# 14    Net-migration - Persons        Count  People  Balance  all
# 15    Net-migration - Persons        Count  People  Balance  all
# 16    Net-migration - Persons        Count  People  Balance  all
# 17    Net-migration - Persons        Count  People  Balance  all
# 18    Net-migration - Persons        Count  People  Balance  all
# 19    Net-migration - Persons        Count  People  Balance  all
# 20    Net-migration - Persons        Count  People  Balance  all
# 21    Net-migration - Persons        Count  People  Balance  all
# 22    Net-migration - Persons        Count  People  Balance  all
# 23    Net-migration - Persons        Count  People  Balance  all
# 24    Net-migration - Persons        Count  People  Balance  all
# 25    Net-migration - Persons        Count  People  Balance  all
# 26    Net-migration - Persons        Count  People  Balance  all
# 27    Net-migration - Persons        Count  People  Balance  all
# 28    Net-migration - Persons        Count  People  Balance  all
# 29    Net-migration - Persons        Count  People  Balance  all
# ...                       ...          ...     ...      ...  ...
# 1536  Net-migration - Females        Count  People  Balance  all
# 1537  Net-migration - Females        Count  People  Balance  all
# 1538  Net-migration - Females        Count  People  Balance  all
# 1539  Net-migration - Females        Count  People  Balance  all
# 1540  Net-migration - Females        Count  People  Balance  all
# 1541  Net-migration - Females        Count  People  Balance  all
# 1542  Net-migration - Females        Count  People  Balance  all
# 1543  Net-migration - Females        Count  People  Balance  all
# 1544  Net-migration - Females        Count  People  Balance  all
# 1545  Net-migration - Females        Count  People  Balance  all
# 1546  Net-migration - Females        Count  People  Balance  all
# 1547  Net-migration - Females        Count  People  Balance  all
# 1548  Net-migration - Females        Count  People  Balance  all
# 1549  Net-migration - Females        Count  People  Balance  all
# 1550  Net-migration - Females        Count  People  Balance  all
# 1551  Net-migration - Females        Count  People  Balance  all
# 1552  Net-migration - Females        Count  People  Balance  all
# 1553  Net-migration - Females        Count  People  Balance  all
# 1554  Net-migration - Females        Count  People  Balance  all
# 1555  Net-migration - Females        Count  People  Balance  all
# 1556  Net-migration - Females        Count  People  Balance  all
# 1557  Net-migration - Females        Count  People  Balance  all
# 1558  Net-migration - Females        Count  People  Balance  all
# 1559  Net-migration - Females        Count  People  Balance  all
# 1560  Net-migration - Females        Count  People  Balance  all
# 1561  Net-migration - Females        Count  People  Balance  all
# 1562  Net-migration - Females        Count  People  Balance  all
# 1563  Net-migration - Females        Count  People  Balance  all
# 1564  Net-migration - Females        Count  People  Balance  all
# 1565  Net-migration - Females        Count  People  Balance  all
#
# [1566 rows x 9 columns]

# %%
new_table.shape
# Out:
# (1566, 9)

# %%
new_table.count()
# Out:
# OBS                              1566
# DATAMARKER                         30
# Mid Year                         1566
# Area of Destination or Origin    1536
# flow                             1566
# Measure Type                     1566
# Unit                             1566
# Flow                             1566
# Age                              1566
# dtype: int64

# %%
new_table = new_table[new_table['Area of Destination or Origin'].isnull() == False]

# %%
new_table = new_table[new_table['Mid Year'].isnull() == False]

# %%
new_table.dtypes
# Out:
# OBS                              float64
# DATAMARKER                        object
# Mid Year                          object
# Area of Destination or Origin     object
# flow                              object
# Measure Type                      object
# Unit                              object
# Flow                              object
# Age                               object
# dtype: object

# %%
new_table.head()
# Out:
#       OBS DATAMARKER Mid Year Area of Destination or Origin  \
# 0   833.0        NaN  2001-02                 Aberdeen City
# 1   385.0        NaN  2002-03                 Aberdeen City
# 2   874.0        NaN  2003-04                 Aberdeen City
# 3  2150.0        NaN  2004-05                 Aberdeen City
# 4  2138.0        NaN  2005-06                 Aberdeen City
#
#                       flow Measure Type    Unit     Flow  Age
# 0  Net-migration - Persons        Count  People  Balance  all
# 1  Net-migration - Persons        Count  People  Balance  all
# 2  Net-migration - Persons        Count  People  Balance  all
# 3  Net-migration - Persons        Count  People  Balance  all
# 4  Net-migration - Persons        Count  People  Balance  all

# %%
new_table['Mid Year'] = new_table['Mid Year'].map(lambda x: str(x)[0:4])

# %%
new_table['Mid Year'] = new_table['Mid Year'] + '-06-30T00:00:00/P1Y'

# %%
new_table['Sex'] = new_table['flow'].map(lambda x: str(x)[16:])

# %%
new_table['Sex'].unique()
# Out:
# array(['Persons', 'Males', 'Females'], dtype=object)

# %%
new_table['Value'] = new_table['OBS'].astype(int)

# %%
new_table['Sex'] = new_table['Sex'].map(
    lambda x: {
        'Persons' : 'T', 
        'Females' : 'F',
        'Males': 'M' 
        }.get(x, x))

# %%
new_table.dtypes
# Out:
# OBS                              float64
# DATAMARKER                        object
# Mid Year                          object
# Area of Destination or Origin     object
# flow                              object
# Measure Type                      object
# Unit                              object
# Flow                              object
# Age                               object
# Sex                               object
# Value                              int32
# dtype: object

# %%
new_table.head()
# Out:
#       OBS DATAMARKER                 Mid Year Area of Destination or Origin  \
# 0   833.0        NaN  2001-06-30T00:00:00/P1Y                 Aberdeen City
# 1   385.0        NaN  2002-06-30T00:00:00/P1Y                 Aberdeen City
# 2   874.0        NaN  2003-06-30T00:00:00/P1Y                 Aberdeen City
# 3  2150.0        NaN  2004-06-30T00:00:00/P1Y                 Aberdeen City
# 4  2138.0        NaN  2005-06-30T00:00:00/P1Y                 Aberdeen City
#
#                       flow Measure Type    Unit     Flow  Age Sex  Value
# 0  Net-migration - Persons        Count  People  Balance  all   T    833
# 1  Net-migration - Persons        Count  People  Balance  all   T    385
# 2  Net-migration - Persons        Count  People  Balance  all   T    874
# 3  Net-migration - Persons        Count  People  Balance  all   T   2150
# 4  Net-migration - Persons        Count  People  Balance  all   T   2138

# %%
new_table['flow'].unique()
# Out:
# array(['Net-migration - Persons', 'Net-migration - Males',
#        'Net-migration - Females'], dtype=object)

# %%
new_table = new_table[['Area of Destination or Origin','Mid Year','Sex','Age', 'Flow','Measure Type','Value','Unit']]

# %%
new_table.dtypes
# Out:
# Area of Destination or Origin    object
# Mid Year                         object
# Sex                              object
# Age                              object
# Flow                             object
# Measure Type                     object
# Value                             int32
# Unit                             object
# dtype: object

# %%
new_table.head(5)
# Out:
#   Area of Destination or Origin                 Mid Year Sex  Age     Flow  \
# 0                 Aberdeen City  2001-06-30T00:00:00/P1Y   T  all  Balance
# 1                 Aberdeen City  2002-06-30T00:00:00/P1Y   T  all  Balance
# 2                 Aberdeen City  2003-06-30T00:00:00/P1Y   T  all  Balance
# 3                 Aberdeen City  2004-06-30T00:00:00/P1Y   T  all  Balance
# 4                 Aberdeen City  2005-06-30T00:00:00/P1Y   T  all  Balance
#
#   Measure Type  Value    Unit
# 0        Count    833  People
# 1        Count    385  People
# 2        Count    874  People
# 3        Count   2150  People
# 4        Count   2138  People

# %%
new_table.tail(5)
# Out:
#      Area of Destination or Origin                 Mid Year Sex  Age     Flow  \
# 1561                  West Lothian  2012-06-30T00:00:00/P1Y   F  all  Balance
# 1562                  West Lothian  2013-06-30T00:00:00/P1Y   F  all  Balance
# 1563                  West Lothian  2014-06-30T00:00:00/P1Y   F  all  Balance
# 1564                  West Lothian  2015-06-30T00:00:00/P1Y   F  all  Balance
# 1565                  West Lothian  2016-06-30T00:00:00/P1Y   F  all  Balance
#
#      Measure Type  Value    Unit
# 1561        Count     14  People
# 1562        Count     36  People
# 1563        Count    103  People
# 1564        Count    183  People
# 1565        Count     79  People

# %%
new_table.count()
# Out:
# Area of Destination or Origin    1536
# Mid Year                         1536
# Sex                              1536
# Age                              1536
# Flow                             1536
# Measure Type                     1536
# Value                            1536
# Unit                             1536
# dtype: int64

# %%
new_table['Sex'].unique()
# Out:
# array(['T', 'M', 'F'], dtype=object)
