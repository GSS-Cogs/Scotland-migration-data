# %% [markdown]
# # Migration between administrative areas and overseas by sex
#
# Tab: `In-Council Area-Sex`

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.nrscotland.gov.uk/statistics-and-data/statistics/' \
                      'statistics-by-theme/migration/migration-statistics/migration-between-scotland-and-overseas')
    scraper.run()
    distribution = scraper.distribution(
        mediaType='application/vnd.ms-excel',
        title='Migration between administrative areas and overseas by sex')
    display(distribution)
    tab = [tab for tab in distribution.as_databaker() if tab.name == 'In-Council Area-Sex'][0]
# Out:
# <h3>Distribution</h3>
# <dl><dt>dct:title</dt><dd>&quot;Migration between administrative areas and overseas by sex&quot;@en</dd>
# <dt>dcat:downloadURL</dt><dd><a href=https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx>&lt;https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx&gt;</a></dd>
# <dt>dcat:mediaType</dt><dd>&quot;application/vnd.ms-excel&quot;</dd>
# </dl>

# %%
observations = tab.excel_ref("B6").expand(RIGHT).expand(DOWN).is_not_blank().is_not_whitespace()
observations
# Out:
# {<H57 5474.0>, <F20 7990.0>, <D11 85.0>, <F80 2133.0>, <N34 371.0>, <L31 383.0>, <P107 140.0>, <H88 108.0>, <J29 2130.0>, <P79 '2015-16'>, <M84 3982.0>, <F11 173.0>, <C11 68.0>, <I14 118.0>, <F54 69.0>, <Q87 538.0>, <I26 226.0>, <C111 100.0>, <B110 75.0>, <D91 80.0>, <H31 685.0>, <F63 110.0>, <O26 158.0>, <H12 524.0>, <F8 446.0>, <O58 449.0>, <G74 664.0>, <J79 '2009-10'>, <B30 390.0>, <D10 7812.0>, <Q47 4285.0>, <Q68 134.0>, <M58 322.0>, <O67 269.0>, <D108 215.0>, <I68 248.0>, <G106 34.0>, <G92 291.0>, <L52 53.0>, <I98 195.0>, <F82 251.0>, <I11 178.0>, <E88 96.0>, <L60 71.0>, <D56 700.0>, <H55 317.0>, <L99 26.0>, <C50 469.0>, <G35 1009.0>, <G90 179.0>, <B71 180.0>, <J26 235.0>, <L25 44.0>, <G99 51.0>, <C45 50.0>, <L56 856.0>, <Q110 62.0>, <N97 79.0>, <K20 10256.0>, <L29 1384.0>, <G27 1181.0>, <P19 2051.0>, <D107 69.0>, <O85 50.0>, <M22 71.0>, <L80 2202.0>, <B77 'In-migration - Females'>, <O45 142.0>, <K82 231.0>, <M37 500.0>, <K52 83.0>, <I85 87.0>, <I81 768.0>, <L93 1106.0>, <Q88 47.0>, <L24 315.0>, <N42 '2013-14'>, <N88 46.0>, <G102 21.0>, <J37 930.0>, <J10 11837.0>, <E107 155.0>, <P17 179.0>, <Q50 643.0>, <K54 71.0>, <M23 88.0>, <E103 795.0>, <F83 248.0>, <C90 87.0>, <Q16 345.0>, <O71 236.0>, <E90 136.0>, <M104 158.0>, <I25 76.0>, <G104 407.0>, <M105 130.0>, <P14 114.0>, <N100 72.0>, <H48 92.0>, <I79 '2008-09'>, <H63 136.0>, <Q7 758.0>, <L65 18.0>, <B58 331.0>, <K61 209.0>, <E100 117.0>, <N28 52.0>, <M86 96.0>, <M43 1788.0>, <G83 283.0>, <H20 9769.0>, <L53 152.0>, <B99 24.0>, <D94 3148.0>, <D58 324.0>, <O32 93.0>, <E34 767.0>, <Q62 35.0>, <Q101 241.0>, <M92 124.0>, <Q59 55.0>, <C106 21.0>, <P31 315.0>, <C34 358.0>, <C35 619.0>, <Q14 106.0>, <O61 176.0>, <C32 33.0>, <M82 126.0>, <L100 66.0>, <B16 234.0>, <C61 162.0>, <Q55 207.0>, <P23 207.0>, <Q21 730.0>, <B46 96.0>, <I58 639.0>, <C21 472.0>, <O86 137.0>, <N84 4565.0>, <L110 45.0>, <E101 345.0>, <G10 10185.0>, <F42 '2005-06'>, <J57 5647.0>, <J28 63.0>, <C30 427.0>, <B89 90.0>, <B23 154.0>, <M88 35.0>, <B14 99.0>, <P96 59.0>, <Q58 389.0>, <K105 191.0>, <L54 39.0>, <L90 255.0>, <N54 53.0>, <H109 477.0>, <Q94 4296.0>, <L97 103.0>, <K85 64.0>, <G64 633.0>, <I97 98.0>, <N26 136.0>, <G59 112.0>, <J54 95.0>, <B104 172.0>, <C72 269.0>, <P111 318.0>, <G56 1081.0>, <L49 122.0>, <E69 25.0>, <E33 345.0>, <E62 45.0>, <G79 '2006-07'>, <C97 63.0>, <N103 554.0>, <M34 308.0>, <J80 2836.0>, <J96 100.0>, <M20 7088.0>, <G50 1007.0>, <O24 332.0>, <K51 56.0>, <J66 1215.0>, <Q95 341.0>, <H61 266.0>, <N85 58.0>, <C23 114.0>, <O97 85.0>, <N44 518.0>, <I48 91.0>, <C59 138.0>, <O15 105.0>, <Q73 73.0>, <Q29 702.0>, <D34 429.0>, <M80 1848.0>, <H73 88.0>, <I54 73.0>, <J65 34.0>, <J21 1309.0>, <Q12 239.0>, <P95 479.0>, <H46 199.0>, <D36 164.0>, <C14 78.0>, <P35 818.0>, <B72 301.0>, <I53 200.0>, <B100 117.0>, <F70 146.0>, <Q9 296.0>, <N91 72.0>, <E95 760.0>, <O62 31.0>, <E74 292.0>, <P104 404.0>, <G105 334.0>, <I105 272.0>, <F59 130.0>, <M28 49.0>, <I30 662.0>, <F107 180.0>, <O37 561.0>, <F44 745.0>, <F58 760.0>, <G93 1210.0>, <J15 154.0>, <D8 136.0>, <B93 917.0>, <Q86 109.0>, <E50 937.0>, <C105 90.0>, <B7 599.0>, <G96 105.0>, <E66 843.0>, <N30 431.0>, <H103 1009.0>, <K12 358.0>, <B83 118.0>, <I90 249.0>, <P48 69.0>, <E86 232.0>, <B95 173.0>, <K46 178.0>, <Q61 108.0>, <F56 1006.0>, <C87 389.0>, <L84 4995.0>, <B21 504.0>, <H89 69.0>, <L89 58.0>, <C92 120.0>, <J62 33.0>, <O60 86.0>, <K103 672.0>, <H59 94.0>, <E108 369.0>, <J35 1249.0>, <E70 190.0>, <I83 207.0>, <Q92 172.0>, <N36 116.0>, <P28 52.0>, <O65 26.0>, <G84 5129.0>, <I8 458.0>, <M56 660.0>, <H70 181.0>, <F45 195.0>, <E94 3715.0>, <F65 32.0>, <P63 93.0>, <O79 '2014-15'>, <Q90 172.0>, <O25 55.0>, <O23 171.0>, <Q71 285.0>, <P91 102.0>, <Q48 84.0>, <N101 223.0>, <F90 164.0>, <G95 793.0>, <I82 240.0>, <J105 191.0>, <F86 246.0>, <M66 466.0>, <O27 623.0>, <K108 264.0>, <B63 96.0>, <N66 687.0>, <O63 80.0>, <L108 211.0>, <J23 207.0>, <N31 283.0>, <J108 315.0>, <L81 502.0>, <M83 132.0>, <M24 227.0>, <P50 674.0>, <B109 371.0>, <K91 63.0>, <K18 502.0>, <J59 100. ...

# %%
observations = observations - tab.excel_ref('B').by_index([38,39,40,41,42,75,76,77,78,79])

# %%
Area  = tab.excel_ref('A6').expand(DOWN).is_not_blank() - tab.excel_ref('A').expand(DOWN).by_index([38,39,40,41,42,75,76,77,78,79])
Area
# Out:
# {<A50 'Dundee City'>, <A64 'North Lanarkshire'>, <A114 '1) Please note that asylum seekers are included for estimates for all years, refugees are included in 2015-16 estimates and onwards.'>, <A61 'Moray'>, <A53 'East Lothian'>, <A36 'West Dunbartonshire'>, <A102 'Orkney Islands'>, <A82 'Angus'>, <A26 'North Ayrshire'>, <A34 'South Lanarkshire'>, <A98 'Moray'>, <A56 'Fife'>, <A72 'Stirling'>, <A109 'Stirling'>, <A32 'Shetland Islands'>, <A31 'Scottish Borders'>, <A58 'Highland'>, <A101 'North Lanarkshire'>, <A19 'Fife'>, <A10 'City of Edinburgh'>, <A108 'South Lanarkshire'>, <A116 '© Crown Copyright 2018'>, <A52 'East Dunbartonshire'>, <A74 'West Lothian'>, <A55 'Falkirk'>, <A54 'East Renfrewshire'>, <A33 'South Ayrshire'>, <A25 'Na h-Eileanan Siar'>, <A73 'West Dunbartonshire'>, <A6 'Aberdeen City'>, <A87 'Dundee City'>, <A27 'North Lanarkshire'>, <A97 'Midlothian'>, <A43 'Aberdeen City'>, <A95 'Highland'>, <A62 'Na h-Eileanan Siar'>, <A110 'West Dunbartonshire'>, <A28 'Orkney Islands'>, <A51 'East Ayrshire'>, <A68 'Scottish Borders'>, <A85 'Clackmannanshire'>, <A103 'Perth and Kinross'>, <A44 'Aberdeenshire'>, <A8 'Angus'>, <A35 'Stirling'>, <A11 'Clackmannanshire'>, <A30 'Renfrewshire'>, <A49 'Dumfries and Galloway'>, <A86 'Dumfries and Galloway'>, <A99 'Na h-Eileanan Siar'>, <A15 'East Dunbartonshire'>, <A65 'Orkney Islands'>, <A23 'Midlothian'>, <A22 'Inverclyde'>, <A16 'East Lothian'>, <A59 'Inverclyde'>, <A12 'Dumfries and Galloway'>, <A18 'Falkirk'>, <A37 'West Lothian'>, <A63 'North Ayrshire'>, <A67 'Renfrewshire'>, <A80 'Aberdeen City'>, <A45 'Angus'>, <A83 'Argyll & Bute'>, <A13 'Dundee City'>, <A60 'Midlothian'>, <A20 'Glasgow City'>, <A89 'East Dunbartonshire'>, <A48 'Clackmannanshire'>, <A81 'Aberdeenshire'>, <A100 'North Ayrshire'>, <A106 'Shetland Islands'>, <A70 'South Ayrshire'>, <A91 'East Renfrewshire'>, <A92 'Falkirk'>, <A96 'Inverclyde'>, <A71 'South Lanarkshire'>, <A24 'Moray'>, <A46 'Argyll & Bute'>, <A14 'East Ayrshire'>, <A111 'West Lothian'>, <A66 'Perth and Kinross'>, <A84 'City of Edinburgh'>, <A17 'East Renfrewshire'>, <A9 'Argyll & Bute'>, <A93 'Fife'>, <A69 'Shetland Islands'>, <A113 'Footnote'>, <A105 'Scottish Borders'>, <A94 'Glasgow City'>, <A47 'City of Edinburgh'>, <A107 'South Ayrshire'>, <A90 'East Lothian'>, <A88 'East Ayrshire'>, <A104 'Renfrewshire'>, <A7 'Aberdeenshire'>, <A21 'Highland'>, <A29 'Perth and Kinross'>, <A57 'Glasgow City'>}

# %%
flow = tab.excel_ref('B').expand(DOWN).by_index([3,40,77])
flow
# Out:
# {<B40 'In-migration - Males'>, <B77 'In-migration - Females'>, <B3 'In-migration - Persons'>}

# %%
midyear = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
midyear
# Out:
# {<G5 '2006-07'>, <Q5 '2016-17'>, <F5 '2005-06'>, <N5 '2013-14'>, <C5 '2002-03'>, <I5 '2008-09'>, <O5 '2014-15'>, <B5 '2001-02'>, <E5 '2004-05'>, <J5 '2009-10'>, <K5 '2010-11'>, <L5 '2011-12'>, <P5 '2015-16'>, <H5 '2007-08'>, <M5 '2012-13'>, <D5 '2003-04'>}

# %%
Dimensions = [
            HDim(midyear,'Mid Year',DIRECTLY,ABOVE),
            HDim(Area,'Area of Destination or Origin', DIRECTLY, LEFT),
            HDim(flow,'flow',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Flow','Inflow'),
            HDimConst('Age', 'all')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#          OBS DATAMARKER Mid Year Area of Destination or Origin  \
# 0     2956.0        NaN  2001-02                 Aberdeen City
# 1     2578.0        NaN  2002-03                 Aberdeen City
# 2     2893.0        NaN  2003-04                 Aberdeen City
# 3     4322.0        NaN  2004-05                 Aberdeen City
# 4     4459.0        NaN  2005-06                 Aberdeen City
# 5     5350.0        NaN  2006-07                 Aberdeen City
# 6     5409.0        NaN  2007-08                 Aberdeen City
# 7     5864.0        NaN  2008-09                 Aberdeen City
# 8     5851.0        NaN  2009-10                 Aberdeen City
# 9     5284.0        NaN  2010-11                 Aberdeen City
# 10    4414.0        NaN  2011-12                 Aberdeen City
# 11    3636.0        NaN  2012-13                 Aberdeen City
# 12    4202.0        NaN  2013-14                 Aberdeen City
# 13    4590.0        NaN  2014-15                 Aberdeen City
# 14    4157.0        NaN  2015-16                 Aberdeen City
# 15    3182.0        NaN  2016-17                 Aberdeen City
# 16     599.0        NaN  2001-02                 Aberdeenshire
# 17     514.0        NaN  2002-03                 Aberdeenshire
# 18     778.0        NaN  2003-04                 Aberdeenshire
# 19    1387.0        NaN  2004-05                 Aberdeenshire
# 20    1557.0        NaN  2005-06                 Aberdeenshire
# 21    1511.0        NaN  2006-07                 Aberdeenshire
# 22    1514.0        NaN  2007-08                 Aberdeenshire
# 23    1513.0        NaN  2008-09                 Aberdeenshire
# 24    1558.0        NaN  2009-10                 Aberdeenshire
# 25    1438.0        NaN  2010-11                 Aberdeenshire
# 26    1062.0        NaN  2011-12                 Aberdeenshire
# 27     978.0        NaN  2012-13                 Aberdeenshire
# 28    1062.0        NaN  2013-14                 Aberdeenshire
# 29    1080.0        NaN  2014-15                 Aberdeenshire
# ...      ...        ...      ...                           ...
# 1536    73.0        NaN  2003-04           West Dunbartonshire
# 1537    99.0        NaN  2004-05           West Dunbartonshire
# 1538    90.0        NaN  2005-06           West Dunbartonshire
# 1539   113.0        NaN  2006-07           West Dunbartonshire
# 1540    68.0        NaN  2007-08           West Dunbartonshire
# 1541    76.0        NaN  2008-09           West Dunbartonshire
# 1542    92.0        NaN  2009-10           West Dunbartonshire
# 1543    75.0        NaN  2010-11           West Dunbartonshire
# 1544    45.0        NaN  2011-12           West Dunbartonshire
# 1545    55.0        NaN  2012-13           West Dunbartonshire
# 1546    61.0        NaN  2013-14           West Dunbartonshire
# 1547    58.0        NaN  2014-15           West Dunbartonshire
# 1548   101.0        NaN  2015-16           West Dunbartonshire
# 1549    62.0        NaN  2016-17           West Dunbartonshire
# 1550   142.0        NaN  2001-02                  West Lothian
# 1551   100.0        NaN  2002-03                  West Lothian
# 1552   168.0        NaN  2003-04                  West Lothian
# 1553   265.0        NaN  2004-05                  West Lothian
# 1554   437.0        NaN  2005-06                  West Lothian
# 1555   584.0        NaN  2006-07                  West Lothian
# 1556   547.0        NaN  2007-08                  West Lothian
# 1557   437.0        NaN  2008-09                  West Lothian
# 1558   442.0        NaN  2009-10                  West Lothian
# 1559   398.0        NaN  2010-11                  West Lothian
# 1560   358.0        NaN  2011-12                  West Lothian
# 1561   232.0        NaN  2012-13                  West Lothian
# 1562   269.0        NaN  2013-14                  West Lothian
# 1563   271.0        NaN  2014-15                  West Lothian
# 1564   318.0        NaN  2015-16                  West Lothian
# 1565   215.0        NaN  2016-17                  West Lothian
#
#                         flow Measure Type    Unit    Flow  Age
# 0     In-migration - Persons        Count  People  Inflow  all
# 1     In-migration - Persons        Count  People  Inflow  all
# 2     In-migration - Persons        Count  People  Inflow  all
# 3     In-migration - Persons        Count  People  Inflow  all
# 4     In-migration - Persons        Count  People  Inflow  all
# 5     In-migration - Persons        Count  People  Inflow  all
# 6     In-migration - Persons        Count  People  Inflow  all
# 7     In-migration - Persons        Count  People  Inflow  all
# 8     In-migration - Persons        Count  People  Inflow  all
# 9     In-migration - Persons        Count  People  Inflow  all
# 10    In-migration - Persons        Count  People  Inflow  all
# 11    In-migration - Persons        Count  People  Inflow  all
# 12    In-migration - Persons        Count  People  Inflow  all
# 13    In-migration - Persons        Count  People  Inflow  all
# 14    In-migration - Persons        Count  People  Inflow  all
# 15    In-migration - Persons        Count  People  Inflow  all
# 16    In-migration - Persons        Count  People  Inflow  all
# 17    In-migration - Persons        Count  People  Inflow  all
# 18    In-migration - Persons        Count  People  Inflow  all
# 19    In-migration - Persons        Count  People  Inflow  all
# 20    In-migration - Persons        Count  People  Inflow  all
# 21    In-migration - Persons        Count  People  Inflow  all
# 22    In-migration - Persons        Count  People  Inflow  all
# 23    In-migration - Persons        Count  People  Inflow  all
# 24    In-migration - Persons        Count  People  Inflow  all
# 25    In-migration - Persons        Count  People  Inflow  all
# 26    In-migration - Persons        Count  People  Inflow  all
# 27    In-migration - Persons        Count  People  Inflow  all
# 28    In-migration - Persons        Count  People  Inflow  all
# 29    In-migration - Persons        Count  People  Inflow  all
# ...                      ...          ...     ...     ...  ...
# 1536  In-migration - Females        Count  People  Inflow  all
# 1537  In-migration - Females        Count  People  Inflow  all
# 1538  In-migration - Females        Count  People  Inflow  all
# 1539  In-migration - Females        Count  People  Inflow  all
# 1540  In-migration - Females        Count  People  Inflow  all
# 1541  In-migration - Females        Count  People  Inflow  all
# 1542  In-migration - Females        Count  People  Inflow  all
# 1543  In-migration - Females        Count  People  Inflow  all
# 1544  In-migration - Females        Count  People  Inflow  all
# 1545  In-migration - Females        Count  People  Inflow  all
# 1546  In-migration - Females        Count  People  Inflow  all
# 1547  In-migration - Females        Count  People  Inflow  all
# 1548  In-migration - Females        Count  People  Inflow  all
# 1549  In-migration - Females        Count  People  Inflow  all
# 1550  In-migration - Females        Count  People  Inflow  all
# 1551  In-migration - Females        Count  People  Inflow  all
# 1552  In-migration - Females        Count  People  Inflow  all
# 1553  In-migration - Females        Count  People  Inflow  all
# 1554  In-migration - Females        Count  People  Inflow  all
# 1555  In-migration - Females        Count  People  Inflow  all
# 1556  In-migration - Females        Count  People  Inflow  all
# 1557  In-migration - Females        Count  People  Inflow  all
# 1558  In-migration - Females        Count  People  Inflow  all
# 1559  In-migration - Females        Count  People  Inflow  all
# 1560  In-migration - Females        Count  People  Inflow  all
# 1561  In-migration - Females        Count  People  Inflow  all
# 1562  In-migration - Females        Count  People  Inflow  all
# 1563  In-migration - Females        Count  People  Inflow  all
# 1564  In-migration - Females        Count  People  Inflow  all
# 1565  In-migration - Females        Count  People  Inflow  all
#
# [1566 rows x 9 columns]

# %%
new_table.shape
# Out:
# (1566, 9)

# %%
new_table.count()
# Out:
# OBS                              1566
# DATAMARKER                         30
# Mid Year                         1566
# Area of Destination or Origin    1536
# flow                             1566
# Measure Type                     1566
# Unit                             1566
# Flow                             1566
# Age                              1566
# dtype: int64

# %%
new_table = new_table[new_table['Area of Destination or Origin'].isnull() == False]

# %%
new_table = new_table[new_table['Mid Year'].isnull() == False]

# %%
new_table.dtypes
# Out:
# OBS                              float64
# DATAMARKER                        object
# Mid Year                          object
# Area of Destination or Origin     object
# flow                              object
# Measure Type                      object
# Unit                              object
# Flow                              object
# Age                               object
# dtype: object

# %%
new_table.head()
# Out:
#       OBS DATAMARKER Mid Year Area of Destination or Origin  \
# 0  2956.0        NaN  2001-02                 Aberdeen City
# 1  2578.0        NaN  2002-03                 Aberdeen City
# 2  2893.0        NaN  2003-04                 Aberdeen City
# 3  4322.0        NaN  2004-05                 Aberdeen City
# 4  4459.0        NaN  2005-06                 Aberdeen City
#
#                      flow Measure Type    Unit    Flow  Age
# 0  In-migration - Persons        Count  People  Inflow  all
# 1  In-migration - Persons        Count  People  Inflow  all
# 2  In-migration - Persons        Count  People  Inflow  all
# 3  In-migration - Persons        Count  People  Inflow  all
# 4  In-migration - Persons        Count  People  Inflow  all

# %%
new_table['Mid Year'] = new_table['Mid Year'].map(lambda x: str(x)[0:4])

# %%
new_table['Mid Year'] = new_table['Mid Year'] + '-06-30T00:00:00/P1Y'

# %%
new_table['Sex'] = new_table['flow'].map(lambda x: str(x)[15:])

# %%
new_table['Sex'].unique()
# Out:
# array(['Persons', 'Males', 'Females'], dtype=object)

# %%
new_table['Value'] = new_table['OBS'].astype(int)

# %%
new_table['Sex'] = new_table['Sex'].map(
    lambda x: {
        'Persons' : 'T', 
        'Females' : 'F',
        'Males': 'M' 
        }.get(x, x))

# %%
new_table.dtypes
# Out:
# OBS                              float64
# DATAMARKER                        object
# Mid Year                          object
# Area of Destination or Origin     object
# flow                              object
# Measure Type                      object
# Unit                              object
# Flow                              object
# Age                               object
# Sex                               object
# Value                              int64
# dtype: object

# %%
new_table.head()
# Out:
#       OBS DATAMARKER                 Mid Year Area of Destination or Origin  \
# 0  2956.0        NaN  2001-06-30T00:00:00/P1Y                 Aberdeen City
# 1  2578.0        NaN  2002-06-30T00:00:00/P1Y                 Aberdeen City
# 2  2893.0        NaN  2003-06-30T00:00:00/P1Y                 Aberdeen City
# 3  4322.0        NaN  2004-06-30T00:00:00/P1Y                 Aberdeen City
# 4  4459.0        NaN  2005-06-30T00:00:00/P1Y                 Aberdeen City
#
#                      flow Measure Type    Unit    Flow  Age Sex  Value
# 0  In-migration - Persons        Count  People  Inflow  all   T   2956
# 1  In-migration - Persons        Count  People  Inflow  all   T   2578
# 2  In-migration - Persons        Count  People  Inflow  all   T   2893
# 3  In-migration - Persons        Count  People  Inflow  all   T   4322
# 4  In-migration - Persons        Count  People  Inflow  all   T   4459

# %%
new_table['flow'].unique()
# Out:
# array(['In-migration - Persons', 'In-migration - Males',
#        'In-migration - Females'], dtype=object)

# %%
new_table = new_table[['Area of Destination or Origin','Mid Year','Sex','Age','Flow','Measure Type','Value','Unit']]

# %%
new_table.dtypes
# Out:
# Area of Destination or Origin    object
# Mid Year                         object
# Sex                              object
# Age                              object
# Flow                             object
# Measure Type                     object
# Value                             int64
# Unit                             object
# dtype: object

# %%
new_table.head(5)
# Out:
#   Area of Destination or Origin                 Mid Year Sex  Age    Flow  \
# 0                 Aberdeen City  2001-06-30T00:00:00/P1Y   T  all  Inflow
# 1                 Aberdeen City  2002-06-30T00:00:00/P1Y   T  all  Inflow
# 2                 Aberdeen City  2003-06-30T00:00:00/P1Y   T  all  Inflow
# 3                 Aberdeen City  2004-06-30T00:00:00/P1Y   T  all  Inflow
# 4                 Aberdeen City  2005-06-30T00:00:00/P1Y   T  all  Inflow
#
#   Measure Type  Value    Unit
# 0        Count   2956  People
# 1        Count   2578  People
# 2        Count   2893  People
# 3        Count   4322  People
# 4        Count   4459  People

# %%
new_table.tail(5)
# Out:
#      Area of Destination or Origin                 Mid Year Sex  Age    Flow  \
# 1561                  West Lothian  2012-06-30T00:00:00/P1Y   F  all  Inflow
# 1562                  West Lothian  2013-06-30T00:00:00/P1Y   F  all  Inflow
# 1563                  West Lothian  2014-06-30T00:00:00/P1Y   F  all  Inflow
# 1564                  West Lothian  2015-06-30T00:00:00/P1Y   F  all  Inflow
# 1565                  West Lothian  2016-06-30T00:00:00/P1Y   F  all  Inflow
#
#      Measure Type  Value    Unit
# 1561        Count    232  People
# 1562        Count    269  People
# 1563        Count    271  People
# 1564        Count    318  People
# 1565        Count    215  People

# %%
new_table.count()
# Out:
# Area of Destination or Origin    1536
# Mid Year                         1536
# Sex                              1536
# Age                              1536
# Flow                             1536
# Measure Type                     1536
# Value                            1536
# Unit                             1536
# dtype: int64

# %%
new_table['Area of Destination or Origin'].unique()
# Out:
# array(['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll & Bute',
#        'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway',
#        'Dundee City', 'East Ayrshire', 'East Dunbartonshire',
#        'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife',
#        'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray',
#        'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire',
#        'Orkney Islands', 'Perth and Kinross', 'Renfrewshire',
#        'Scottish Borders', 'Shetland Islands', 'South Ayrshire',
#        'South Lanarkshire', 'Stirling', 'West Dunbartonshire',
#        'West Lothian'], dtype=object)
