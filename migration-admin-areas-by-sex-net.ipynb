# %% [markdown]
# # Migration between administrative areas and overseas by sex
#
# Tab: Net-Council Area-Sex

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.nrscotland.gov.uk/statistics-and-data/statistics/' \
                      'statistics-by-theme/migration/migration-statistics/migration-between-scotland-and-overseas')
#     scraper.run()
    distribution = scraper.distribution(
        mediaType='application/vnd.ms-excel',
        title='Migration between administrative areas and overseas by sex')
    display(distribution)
    tab = [tab for tab in distribution.as_databaker() if tab.name == 'Net-Council Area-Sex'][0]
# Out:
# <h3>Distribution</h3>
# <dl><dt>dct:title</dt><dd>&quot;Migration between administrative areas and overseas by sex&quot;@en</dd>
# <dt>dcat:downloadURL</dt><dd><a href=https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx>&lt;https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z1-overseas-mig-flows-admin-sex-hb-2001-02-latest-july-18.xlsx&gt;</a></dd>
# <dt>dcat:mediaType</dt><dd>&quot;application/vnd.ms-excel&quot;</dd>
# </dl>

# %%
cell = tab.filter('Council areas')
flow = cell.fill(RIGHT).is_not_blank().is_not_whitespace()
midyear = cell.shift(0,2).expand(RIGHT).is_not_blank().is_not_whitespace()
observations = midyear.shift(0,1).expand(DOWN).is_not_blank().is_not_whitespace().is_not_bold() 
observations = observations.filter(lambda x: type(x.value) != str or 'Year' not in x.value) - midyear - flow
area = cell.expand(DOWN).is_not_blank().is_not_whitespace()

# %%
Dimensions = [
            HDim(midyear,'Mid Year',DIRECTLY,ABOVE),
            HDim(area,'Domestic geography', DIRECTLY, LEFT),
            HDim(flow,'flow',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Flow','balance'),
            HDimConst('Age', 'all')
            ]
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)
tidy = c1.topandas()

# %%
tidy['Mid Year'] = tidy['Mid Year'].map(lambda x: str(x)[0:4]) + '-06-30T00:00:00/P1Y'
tidy['Foreign geography'] = 'nrs/overseas'

# %%
for col in tidy.columns:
    if col not in ['OBS']:
        tidy[col] = tidy[col].astype('category')
        display(col)
        display(tidy[col].cat.categories)
# Out:
# 'Mid Year'
# Index(['2001-06-30T00:00:00/P1Y', '2002-06-30T00:00:00/P1Y',
#        '2003-06-30T00:00:00/P1Y', '2004-06-30T00:00:00/P1Y',
#        '2005-06-30T00:00:00/P1Y', '2006-06-30T00:00:00/P1Y',
#        '2007-06-30T00:00:00/P1Y', '2008-06-30T00:00:00/P1Y',
#        '2009-06-30T00:00:00/P1Y', '2010-06-30T00:00:00/P1Y',
#        '2011-06-30T00:00:00/P1Y', '2012-06-30T00:00:00/P1Y',
#        '2013-06-30T00:00:00/P1Y', '2014-06-30T00:00:00/P1Y',
#        '2015-06-30T00:00:00/P1Y', '2016-06-30T00:00:00/P1Y'],
#       dtype='object')
# 'Domestic geography'
# Index(['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll & Bute',
#        'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway',
#        'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian',
#        'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland',
#        'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar',
#        'North Ayrshire', 'North Lanarkshire', 'Orkney Islands',
#        'Perth and Kinross', 'Renfrewshire', 'Scottish Borders',
#        'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling',
#        'West Dunbartonshire', 'West Lothian'],
#       dtype='object')
# 'flow'
# Index(['Net-migration - Females', 'Net-migration - Males',
#        'Net-migration - Persons'],
#       dtype='object')
# 'Measure Type'
# Index(['Count'], dtype='object')
# 'Unit'
# Index(['People'], dtype='object')
# 'Flow'
# Index(['balance'], dtype='object')
# 'Age'
# Index(['all'], dtype='object')
# 'Foreign geography'
# Index(['nrs/overseas'], dtype='object')

# %%
tidy['Sex'] = tidy['flow'].map(lambda x: str(x)[16:])
tidy['Sex'] = tidy['Sex'].map(
    lambda x: {
        'Persons' : 'T', 
        'Females' : 'F',
        'Males': 'M' 
        }.get(x, x))

# %%
import numpy as np
tidy['OBS'].replace('', np.nan, inplace=True)
tidy.dropna(subset=['OBS'], inplace=True)
if 'DATAMARKER' in tidy.columns:
    tidy.drop(columns=['DATAMARKER'], inplace=True)
tidy.rename(columns={'OBS': 'Value'}, inplace=True)
tidy['Value'] = tidy['Value'].astype(int)

# %%
tidy = tidy[['Domestic geography','Foreign geography','Mid Year','Sex','Age', 'Flow','Measure Type','Value','Unit']]

# %%
tidy
# Out:
#        Domestic geography Foreign geography                 Mid Year Sex  Age  \
# 0           Aberdeen City      nrs/overseas  2001-06-30T00:00:00/P1Y   T  all
# 1           Aberdeen City      nrs/overseas  2002-06-30T00:00:00/P1Y   T  all
# 2           Aberdeen City      nrs/overseas  2003-06-30T00:00:00/P1Y   T  all
# 3           Aberdeen City      nrs/overseas  2004-06-30T00:00:00/P1Y   T  all
# 4           Aberdeen City      nrs/overseas  2005-06-30T00:00:00/P1Y   T  all
# 5           Aberdeen City      nrs/overseas  2006-06-30T00:00:00/P1Y   T  all
# 6           Aberdeen City      nrs/overseas  2007-06-30T00:00:00/P1Y   T  all
# 7           Aberdeen City      nrs/overseas  2008-06-30T00:00:00/P1Y   T  all
# 8           Aberdeen City      nrs/overseas  2009-06-30T00:00:00/P1Y   T  all
# 9           Aberdeen City      nrs/overseas  2010-06-30T00:00:00/P1Y   T  all
# 10          Aberdeen City      nrs/overseas  2011-06-30T00:00:00/P1Y   T  all
# 11          Aberdeen City      nrs/overseas  2012-06-30T00:00:00/P1Y   T  all
# 12          Aberdeen City      nrs/overseas  2013-06-30T00:00:00/P1Y   T  all
# 13          Aberdeen City      nrs/overseas  2014-06-30T00:00:00/P1Y   T  all
# 14          Aberdeen City      nrs/overseas  2015-06-30T00:00:00/P1Y   T  all
# 15          Aberdeen City      nrs/overseas  2016-06-30T00:00:00/P1Y   T  all
# 1524         West Lothian      nrs/overseas  2005-06-30T00:00:00/P1Y   F  all
# 1525         West Lothian      nrs/overseas  2006-06-30T00:00:00/P1Y   F  all
# 1526         West Lothian      nrs/overseas  2007-06-30T00:00:00/P1Y   F  all
# 1527         West Lothian      nrs/overseas  2008-06-30T00:00:00/P1Y   F  all
# 1528         West Lothian      nrs/overseas  2009-06-30T00:00:00/P1Y   F  all
# 1529         West Lothian      nrs/overseas  2010-06-30T00:00:00/P1Y   F  all
# 1530         West Lothian      nrs/overseas  2011-06-30T00:00:00/P1Y   F  all
# 1531         West Lothian      nrs/overseas  2012-06-30T00:00:00/P1Y   F  all
# 1532         West Lothian      nrs/overseas  2013-06-30T00:00:00/P1Y   F  all
# 1533         West Lothian      nrs/overseas  2014-06-30T00:00:00/P1Y   F  all
# 1534         West Lothian      nrs/overseas  2015-06-30T00:00:00/P1Y   F  all
# 1535         West Lothian      nrs/overseas  2016-06-30T00:00:00/P1Y   F  all
#
#          Flow Measure Type  Value    Unit
# 0     balance        Count    833  People
# 1     balance        Count    385  People
# 2     balance        Count    874  People
# 3     balance        Count   2150  People
# 4     balance        Count   2138  People
# 5     balance        Count   3752  People
# 6     balance        Count   3030  People
# 7     balance        Count   3669  People
# 8     balance        Count   3742  People
# 9     balance        Count   4130  People
# 10    balance        Count   2102  People
# 11    balance        Count   1302  People
# 12    balance        Count   1965  People
# 13    balance        Count   3189  People
# 14    balance        Count   2474  People
# 15    balance        Count   1491  People
# 16    balance        Count   -138  People
# 17    balance        Count   -334  People
# 18    balance        Count    127  People
# 19    balance        Count    623  People
# 20    balance        Count    655  People
# 21    balance        Count    836  People
# 22    balance        Count    405  People
# 23    balance        Count    605  People
# 24    balance        Count    719  People
# 25    balance        Count    723  People
# 26    balance        Count    209  People
# 27    balance        Count    116  People
# 28    balance        Count    124  People
# 29    balance        Count    256  People
# ...       ...          ...    ...     ...
# 1506  balance        Count    -41  People
# 1507  balance        Count    -31  People
# 1508  balance        Count    -18  People
# 1509  balance        Count     21  People
# 1510  balance        Count    -40  People
# 1511  balance        Count    -32  People
# 1512  balance        Count     26  People
# 1513  balance        Count     25  People
# 1514  balance        Count    -34  People
# 1515  balance        Count    -21  People
# 1516  balance        Count    -12  People
# 1517  balance        Count    -10  People
# 1518  balance        Count     49  People
# 1519  balance        Count      2  People
# 1520  balance        Count    -61  People
# 1521  balance        Count    -79  People
# 1522  balance        Count    -24  People
# 1523  balance        Count     91  People
# 1524  balance        Count    268  People
# 1525  balance        Count    410  People
# 1526  balance        Count    266  People
# 1527  balance        Count    172  People
# 1528  balance        Count    191  People
# 1529  balance        Count    243  People
# 1530  balance        Count    129  People
# 1531  balance        Count     14  People
# 1532  balance        Count     36  People
# 1533  balance        Count    103  People
# 1534  balance        Count    183  People
# 1535  balance        Count     79  People
#
# [1536 rows x 9 columns]
