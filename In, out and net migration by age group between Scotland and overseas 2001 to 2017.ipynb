# %% [markdown]
# https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx'
inputFile = sourceFolder / 'tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx

# %%
sheetid = ['AG 2001-02', 'AG 2002-03','AG 2003-04','AG 2004-05','AG 2005-06','AG 2006-07',
           'AG 2007-08','AG 2008-09','AG 2009-10','AG 2010-11','AG 2011-12','AG 2012-13',
            'AG 2013-14','AG 2014-15','AG 2015-16','AG 2016-17']

# %%
Final_table = pd.DataFrame()

# %%
for sheet in sheetid:
    tab = loadxlstabs(inputFile, sheetids = sheet)[0]
    observations = tab.excel_ref("B7").expand(RIGHT).expand(DOWN).is_not_blank().is_not_whitespace()
    area = tab.excel_ref('A').expand(DOWN).by_index([4,11,18,23])
    age = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
    flow = tab.excel_ref('A7').expand(DOWN)
    per = tab.excel_ref('B6').expand(RIGHT).is_not_blank()
    Dimensions = [
            HDimConst('Mid Year',str(sheet[3:7])+'-06-30T00:00:00/P1Y'),
            HDim(flow,'Flow',DIRECTLY, LEFT),
            HDim(age,'Age',DIRECTLY, ABOVE),
            HDim(per,'per',DIRECTLY, ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Sex','T'),
            HDimConst('Area of Destination or Origin','Movements between Scotland and the rest of the UK')
            ]
    c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
    new_table = c1.topandas()
    new_table = new_table[new_table['per'] != '%']
    new_table['Value'] = pd.to_numeric(new_table['OBS'], errors='coerce').fillna(0)
    new_table['Value'] = new_table['Value'].astype(int)
    new_table = new_table[new_table['Flow'] != '']
    new_table['Flow'] = new_table['Flow'].map(
    lambda x: {
        'IN' : 'Inflow', 
        'OUT' : 'Outflow',
        'NET': 'Balance' 
        }.get(x, x))
    new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('+', '-plus'))
    new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('All ages', 'all'))
    new_table['Age'] = 'nrs/' + new_table['Age']
    new_table = new_table[new_table['Value'] != 0 ]
    new_table = new_table[['Area of Destination or Origin','Mid Year','Sex','Age','Flow','Measure Type','Value','Unit']]
    Final_table = pd.concat([Final_table, new_table])
# Out:
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2001-02']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2002-03']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2003-04']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2004-05']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2005-06']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2006-07']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2007-08']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2008-09']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2009-10']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2010-11']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2011-12']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2012-13']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2013-14']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2014-15']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2015-16']
#
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['AG 2016-17']

# %%
Final_table
# Out:
#                          Area of Destination or Origin  \
# 0    Movements between Scotland and the rest of the UK
# 2    Movements between Scotland and the rest of the UK
# 4    Movements between Scotland and the rest of the UK
# 6    Movements between Scotland and the rest of the UK
# 8    Movements between Scotland and the rest of the UK
# 10   Movements between Scotland and the rest of the UK
# 12   Movements between Scotland and the rest of the UK
# 14   Movements between Scotland and the rest of the UK
# 16   Movements between Scotland and the rest of the UK
# 18   Movements between Scotland and the rest of the UK
# 20   Movements between Scotland and the rest of the UK
# 14   2001-06-30T00:00:00/P1Y   T    nrs/75-84   Inflow        Count      882
# 16   2001-06-30T00:00:00/P1Y   T  nrs/85-plus   Inflow        Count      372
# 18   2001-06-30T00:00:00/P1Y   T      nrs/all   Inflow        Count    54397
# 20   2001-06-30T00:00:00/P1Y   T     nrs/0-15  Outflow        Count     8089
# 22   2001-06-30T00:00:00/P1Y   T    nrs/16-24  Outflow        Count    12796
# 24   2001-06-30T00:00:00/P1Y   T    nrs/25-34  Outflow        Count    14551
# 26   2001-06-30T00:00:00/P1Y   T    nrs/35-44  Outflow        Count     7053
# 28   2001-06-30T00:00:00/P1Y   T    nrs/45-54  Outflow        Count     3347
# 30   2001-06-30T00:00:00/P1Y   T    nrs/55-64  Outflow        Count     1951
# 32   2001-06-30T00:00:00/P1Y   T    nrs/65-74  Outflow        Count     1029
# 34   2001-06-30T00:00:00/P1Y   T    nrs/75-84  Outflow        Count      621
# 36   2001-06-30T00:00:00/P1Y   T  nrs/85-plus  Outflow        Count      264
# 38   2001-06-30T00:00:00/P1Y   T      nrs/all  Outflow        Count    49701
# 40   2001-06-30T00:00:00/P1Y   T     nrs/0-15  Balance        Count     1222
# 41   2001-06-30T00:00:00/P1Y   T    nrs/16-24  Balance        Count       -9
# 42   2001-06-30T00:00:00/P1Y   T    nrs/25-34  Balance        Count     -838
# 43   2001-06-30T00:00:00/P1Y   T    nrs/35-44  Balance        Count      985
# 44   2001-06-30T00:00:00/P1Y   T    nrs/45-54  Balance        Count     1121
# 45   2001-06-30T00:00:00/P1Y   T    nrs/55-64  Balance        Count     1306
# 46   2001-06-30T00:00:00/P1Y   T    nrs/65-74  Balance        Count      540
# 47   2001-06-30T00:00:00/P1Y   T    nrs/75-84  Balance        Count      261
# 48   2001-06-30T00:00:00/P1Y   T  nrs/85-plus  Balance        Count      108
# 49   2001-06-30T00:00:00/P1Y   T      nrs/all  Balance        Count     4696
# ..                       ...  ..          ...      ...          ...      ...
# 120  2016-06-30T00:00:00/P1Y   T     nrs/0-15  Balance        Count     2285
# 121  2016-06-30T00:00:00/P1Y   T    nrs/16-24  Balance        Count     7013
# 122  2016-06-30T00:00:00/P1Y   T    nrs/25-34  Balance        Count     3299
# 123  2016-06-30T00:00:00/P1Y   T    nrs/35-44  Balance        Count      964
# 124  2016-06-30T00:00:00/P1Y   T    nrs/45-54  Balance        Count      215
# 125  2016-06-30T00:00:00/P1Y   T    nrs/55-64  Balance        Count      -61
# 126  2016-06-30T00:00:00/P1Y   T    nrs/65-74  Balance        Count     -156
# 127  2016-06-30T00:00:00/P1Y   T    nrs/75-84  Balance        Count     -105
# 128  2016-06-30T00:00:00/P1Y   T  nrs/85-plus  Balance        Count      -54
# 129  2016-06-30T00:00:00/P1Y   T      nrs/all  Balance        Count    13400
# 150  2016-06-30T00:00:00/P1Y   T     nrs/0-15  Balance        Count     3775
# 151  2016-06-30T00:00:00/P1Y   T    nrs/16-24  Balance        Count     9184
# 152  2016-06-30T00:00:00/P1Y   T    nrs/25-34  Balance        Count     4405
# 153  2016-06-30T00:00:00/P1Y   T    nrs/35-44  Balance        Count     2912
# 154  2016-06-30T00:00:00/P1Y   T    nrs/45-54  Balance        Count     1844
# 155  2016-06-30T00:00:00/P1Y   T    nrs/55-64  Balance        Count     1443
# 156  2016-06-30T00:00:00/P1Y   T    nrs/65-74  Balance        Count      338
# 157  2016-06-30T00:00:00/P1Y   T    nrs/75-84  Balance        Count      -45
# 158  2016-06-30T00:00:00/P1Y   T  nrs/85-plus  Balance        Count       -1
# 159  2016-06-30T00:00:00/P1Y   T      nrs/all  Balance        Count    23855
# 190  2016-06-30T00:00:00/P1Y   T     nrs/0-15    Total        Count   917442
# 192  2016-06-30T00:00:00/P1Y   T    nrs/16-24    Total        Count   593361
# 194  2016-06-30T00:00:00/P1Y   T    nrs/25-34    Total        Count   737328
# 196  2016-06-30T00:00:00/P1Y   T    nrs/35-44    Total        Count   664086
# 198  2016-06-30T00:00:00/P1Y   T    nrs/45-54    Total        Count   792119
# 200  2016-06-30T00:00:00/P1Y   T    nrs/55-64    Total        Count   707897
# 202  2016-06-30T00:00:00/P1Y   T    nrs/65-74    Total        Count   564596
# 204  2016-06-30T00:00:00/P1Y   T    nrs/75-84    Total        Count   326155
# 206  2016-06-30T00:00:00/P1Y   T  nrs/85-plus    Total        Count   121816
# 208  2016-06-30T00:00:00/P1Y   T      nrs/all    Total        Count  5424800
#
#        Unit
# 0    People
# 2    People
# 4    People
# 6    People
# 8    People
# 10   People
# 12   People
# 14   People
# 16   People
# 18   People
# 20   People
# 22   People
# 24   People
# 26   People
# 28   People
# 30   People
# 32   People
# 34   People
# 36   People
# 38   People
# 40   People
# 41   People
# 42   People
# 43   People
# 44   People
# 45   People
# 46   People
# 47   People
# 48   People
# 49   People
# ..      ...
# 120  People
# 121  People
# 122  People
# 123  People
# 124  People
# 125  People
# 126  People
# 127  People
# 128  People
# 129  People
# 150  People
# 151  People
# 152  People
# 153  People
# 154  People
# 155  People
# 156  People
# 157  People
# 158  People
# 159  People
# 190  People
# 192  People
# 194  People
# 196  People
# 198  People
# 200  People
# 202  People
# 204  People
# 206  People
# 208  People
#
# [1179 rows x 8 columns]

# %%
Final_table.count()
# Out:
# Area of Destination or Origin    1179
# Mid Year                         1179
# Sex                              1179
# Age                              1179
# Flow                             1179
# Measure Type                     1179
# Value                            1179
# Unit                             1179
# dtype: int64
