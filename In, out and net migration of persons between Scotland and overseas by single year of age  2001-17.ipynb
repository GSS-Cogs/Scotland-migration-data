# %% [markdown]
# https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx'
inputFile = sourceFolder / 'tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.nrscotland.gov.uk/files//statistics/migration/2018-july/tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx

# %%
Final_table = pd.DataFrame()

# %%
tab = loadxlstabs(inputFile, sheetids ='SYOA Persons (2001-)')[0]
observations = tab.excel_ref("B6").expand(RIGHT).expand(DOWN).is_not_blank().is_not_whitespace()
age = tab.excel_ref('C5').expand(RIGHT).is_not_blank()
flow = tab.excel_ref('A').expand(DOWN).by_index([3,23,43])
year = tab.excel_ref('A6').expand(DOWN) - tab.excel_ref('A63').expand(DOWN)
Dimensions = [
            HDim(year,'Mid Year',DIRECTLY, LEFT),
            HDim(flow,'Flow',CLOSEST, ABOVE),
            HDim(age,'Age',DIRECTLY, ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Sex','T'),
            HDimConst('Area of Destination or Origin','migration of persons from overseas')
    ]
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
new_table = c1.topandas()
new_table['Value'] = pd.to_numeric(new_table['OBS'], errors='coerce').fillna(0)
new_table['Value'] = new_table['Value'].astype(int)
new_table['Flow'] = new_table['Flow'].map(
    lambda x: {
        'In migration of persons from overseas 2001-02 to latest' : 'Inflow', 
        'Out migration of persons to overseas 2001-02 to latest' : 'Outflow',
        'Net migration of persons from overseas 2001-02 to latest': 'Balance' 
        }.get(x, x))
new_table['Age'] = new_table['Age'].astype(str)
new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('None', 'all'))
new_table['Age'] = 'year/' + new_table['Age']
new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('.0', ''))
Final_table = pd.concat([Final_table, new_table])
# Out:
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['SYOA Persons (2001-)']

# %%
tab = loadxlstabs(inputFile, sheetids ='SYOA Males (2001-)')[0]
observations = tab.excel_ref("B6").expand(RIGHT).expand(DOWN).is_not_blank().is_not_whitespace()
age = tab.excel_ref('C5').expand(RIGHT).is_not_blank()
flow = tab.excel_ref('A').expand(DOWN).by_index([3,23,43])
year = tab.excel_ref('A6').expand(DOWN) - tab.excel_ref('A63').expand(DOWN)
Dimensions = [
            HDim(year,'Mid Year',DIRECTLY, LEFT),
            HDim(flow,'Flow',CLOSEST, ABOVE),
            HDim(age,'Age',DIRECTLY, ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Sex','M'),
            HDimConst('Area of Destination or Origin','migration of persons from overseas')
    ]
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
new_table = c1.topandas()
new_table['Value'] = pd.to_numeric(new_table['OBS'], errors='coerce').fillna(0)
new_table['Value'] = new_table['Value'].astype(int)
new_table['Flow'] = new_table['Flow'].map(
    lambda x: {
        'In migration of persons from overseas 2001-02 to latest' : 'Inflow', 
        'Out migration of persons to overseas 2001-02 to latest' : 'Outflow',
        'Net migration of persons from overseas 2001-02 to latest': 'Balance' 
        }.get(x, x))
new_table['Age'] = new_table['Age'].astype(str)
new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('None', 'all'))
new_table['Age'] = 'year/' + new_table['Age']
new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('.0', ''))
Final_table = pd.concat([Final_table, new_table])
# Out:
# Loading in\tab-z2-overseas-mig-flows-by-age-scotland-2001-02-latest-july-18.xlsx which has size 210662 bytes
# Table names: ['SYOA Males (2001-)']

# %%
Final_table = Final_table[['Area of Destination or Origin','Mid Year','Sex','Age','Flow','Measure Type','Value','Unit']]

# %%
Final_table
# Out:
#            Area of Destination or Origin Mid Year Sex       Age  \
# 0     migration of persons from overseas  2001-02   T  year/all
# 1     migration of persons from overseas  2001-02   T    year/0
# 2     migration of persons from overseas  2001-02   T    year/1
# 3     migration of persons from overseas  2001-02   T    year/2
# 14                                               Inflow        Count    206
# 15                                               Inflow        Count    262
# 16                                               Inflow        Count    255
# 17                                               Inflow        Count    407
# 18                                               Inflow        Count    424
# 19                                               Inflow        Count    547
# 20                                               Inflow        Count    917
# 21                                               Inflow        Count   1150
# 22                                               Inflow        Count   1577
# 23                                               Inflow        Count   1481
# 24                                               Inflow        Count   1590
# 25                                               Inflow        Count   1455
# 26                                               Inflow        Count   1413
# 27                                               Inflow        Count   1168
# 28                                               Inflow        Count   1089
# 29                                               Inflow        Count    975
# ...                                                 ...          ...    ...
# 4588  Net migration of males from overseas 2001-02 t...        Count     -5
# 4589  Net migration of males from overseas 2001-02 t...        Count     -7
# 4590  Net migration of males from overseas 2001-02 t...        Count    -15
# 4591  Net migration of males from overseas 2001-02 t...        Count     -4
# 4592  Net migration of males from overseas 2001-02 t...        Count    -13
# 4593  Net migration of males from overseas 2001-02 t...        Count     -8
# 4594  Net migration of males from overseas 2001-02 t...        Count     -8
# 4595  Net migration of males from overseas 2001-02 t...        Count     -6
# 4596  Net migration of males from overseas 2001-02 t...        Count    -13
# 4597  Net migration of males from overseas 2001-02 t...        Count    -13
# 4598  Net migration of males from overseas 2001-02 t...        Count     -8
# 4599  Net migration of males from overseas 2001-02 t...        Count     -3
# 4600  Net migration of males from overseas 2001-02 t...        Count     -6
# 4601  Net migration of males from overseas 2001-02 t...        Count     -7
# 4602  Net migration of males from overseas 2001-02 t...        Count     -4
# 4603  Net migration of males from overseas 2001-02 t...        Count     -8
# 4604  Net migration of males from overseas 2001-02 t...        Count     -5
# 4605  Net migration of males from overseas 2001-02 t...        Count     -6
# 4606  Net migration of males from overseas 2001-02 t...        Count     -4
# 4607  Net migration of males from overseas 2001-02 t...        Count     -1
# 4608  Net migration of males from overseas 2001-02 t...        Count     -1
# 4609  Net migration of males from overseas 2001-02 t...        Count     -4
# 4610  Net migration of males from overseas 2001-02 t...        Count     -4
# 4611  Net migration of males from overseas 2001-02 t...        Count      0
# 4612  Net migration of males from overseas 2001-02 t...        Count     -3
# 4613  Net migration of males from overseas 2001-02 t...        Count     -4
# 4614  Net migration of males from overseas 2001-02 t...        Count      0
# 4615  Net migration of males from overseas 2001-02 t...        Count     -1
# 4616  Net migration of males from overseas 2001-02 t...        Count      2
# 4617  Net migration of males from overseas 2001-02 t...        Count     -4
#
#         Unit
# 0     People
# 1     People
# 2     People
# 3     People
# 4     People
# 5     People
# 6     People
# 7     People
# 8     People
# 9     People
# 10    People
# 11    People
# 12    People
# 13    People
# 14    People
# 15    People
# 16    People
# 17    People
# 18    People
# 19    People
# 20    People
# 21    People
# 22    People
# 23    People
# 24    People
# 25    People
# 26    People
# 27    People
# 28    People
# 29    People
# ...      ...
# 4588  People
# 4589  People
# 4590  People
# 4591  People
# 4592  People
# 4593  People
# 4594  People
# 4595  People
# 4596  People
# 4597  People
# 4598  People
# 4599  People
# 4600  People
# 4601  People
# 4602  People
# 4603  People
# 4604  People
# 4605  People
# 4606  People
# 4607  People
# 4608  People
# 4609  People
# 4610  People
# 4611  People
# 4612  People
# 4613  People
# 4614  People
# 4615  People
# 4616  People
# 4617  People
#
# [9236 rows x 8 columns]

# %%
Final_table.count()
# Out:
# Area of Destination or Origin    9236
# Mid Year                         9236
# Sex                              9236
# Age                              9236
# Flow                             9236
# Measure Type                     9236
# Value                            9236
# Unit                             9236
# dtype: int64
